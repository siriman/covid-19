# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv",index_col=2)

# %%
df.head()
# Out:
#                 Unnamed: 0 Province/State      Lat      Long  1/22/20  \
# Country/Region
# Thailand                 0            NaN  15.0000  101.0000        2
# Japan                    1            NaN  36.0000  138.0000        2
# Singapore                2            NaN   1.2833  103.8333        0
# Nepal                    3            NaN  28.1667   84.2500        0
# Malaysia                 4            NaN   2.5000  112.5000        0
#
#                 1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/11/20  \
# Country/Region                                               ...
# Thailand              3        5        7        8        8  ...       59
# Japan                 1        2        2        4        4  ...      639
# Singapore             1        3        3        4        5  ...      178
# Nepal                 0        0        1        1        1  ...        1
# Malaysia              0        0        3        4        4  ...      149
#
# ...

# %%
df=df.drop(["Unnamed: 0", "Province/State","Lat", "Long" ], axis=1)

# %%
df.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Thailand              2        3        5        7        8        8       14
# Japan                 2        1        2        2        4        4        7
# Singapore             0        1        3        3        4        5        7
# Nepal                 0        0        0        1        1        1        1
# Malaysia              0        0        0        3        4        4        4
#
#                 1/29/20  1/30/20  1/31/20  ...  3/11/20  3/12/20  3/13/20  \
# Country/Region                             ...
# Thailand             14       14       19  ...       59       70       75
# Japan                 7       11       15  ...      639      639      701
# Singapore             7       10       13  ...      178      178      200
# Nepal                 1        1        1  ...        1        1        1
# ...

# %%
df_trans=df.T

# %%
df_trans.head()
# Out:
# Country/Region  Thailand  Japan  Singapore  Nepal  Malaysia  Canada  \
# 1/22/20                2      2          0      0         0       0
# 1/23/20                3      1          1      0         0       0
# 1/24/20                5      2          3      0         0       0
# 1/25/20                7      2          3      1         3       0
# 1/26/20                8      4          4      1         4       0
#
# Country/Region  Australia  Australia  Australia  Cambodia  ...  Nicaragua  \
# 1/22/20                 0          0          0         0  ...          0
# 1/23/20                 0          0          0         0  ...          0
# 1/24/20                 0          0          0         0  ...          0
# 1/25/20                 0          0          0         0  ...          0
# 1/26/20                 3          1          0         0  ...          0
#
# Country/Region  Madagascar  Haiti  Angola  Cabo Verde  Netherlands  Niger  \
# ...

# %%
df_trans.index
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20'],
#       dtype='object')

# %%
df_trans.index=pd.to_datetime(df_trans.index)

# %%
df_trans.head()
# Out:
# Country/Region  Thailand  Japan  Singapore  Nepal  Malaysia  Canada  \
# 2020-01-22             2      2          0      0         0       0
# 2020-01-23             3      1          1      0         0       0
# 2020-01-24             5      2          3      0         0       0
# 2020-01-25             7      2          3      1         3       0
# 2020-01-26             8      4          4      1         4       0
#
# Country/Region  Australia  Australia  Australia  Cambodia  ...  Nicaragua  \
# 2020-01-22              0          0          0         0  ...          0
# 2020-01-23              0          0          0         0  ...          0
# 2020-01-24              0          0          0         0  ...          0
# 2020-01-25              0          0          0         0  ...          0
# 2020-01-26              3          1          0         0  ...          0
#
# Country/Region  Madagascar  Haiti  Angola  Cabo Verde  Netherlands  Niger  \
# ...

# %%
df_trans.columns.name=None

# %%
df_trans.index.name="date"

# %%
df_trans.head()
# Out:
#             Thailand  Japan  Singapore  Nepal  Malaysia  Canada  Australia  \
# date
# 2020-01-22         2      2          0      0         0       0          0
# 2020-01-23         3      1          1      0         0       0          0
# 2020-01-24         5      2          3      0         0       0          0
# 2020-01-25         7      2          3      1         3       0          0
# 2020-01-26         8      4          4      1         4       0          3
#
#             Australia  Australia  Cambodia  ...  Nicaragua  Madagascar  Haiti  \
# date                                        ...
# 2020-01-22          0          0         0  ...          0           0      0
# 2020-01-23          0          0         0  ...          0           0      0
# 2020-01-24          0          0         0  ...          0           0      0
# 2020-01-25          0          0         0  ...          0           0      0
# ...

# %%
df_trans.to_csv("new_data.csv")
